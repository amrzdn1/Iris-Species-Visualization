# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Data=pd.read_csv('D:/Data/Intership/archive/Iris.csv')
Data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.1           3.5            1.4           0.2  \
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df=Data.copy()

# %% [markdown]
# # Data_Cleaning

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.1           3.5            1.4           0.2  \
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# # visualization

# %%
sns.countplot(x='Species',data=df)
# Out:
# <Axes: xlabel='Species', ylabel='count'>

# %%
df['SepalLengthCm'].hist(bins=20)
# Out:
# <Axes: >

# %%
sns.displot(df['SepalWidthCm'], kind="hist", bins=20)

# %%
sns.displot(data=df,x='PetalLengthCm',bins=10)

# %%
sns.displot(data=df,x='PetalWidthCm',bins=10)

# %%
sns.kdeplot(data=df,x='SepalLengthCm',fill=True)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Density'>

# %%
sns.kdeplot(data=df,x='SepalWidthCm',fill=True)
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='Density'>

# %%
sns.kdeplot(data=df,x='PetalLengthCm')
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='Density'>

# %%
sns.kdeplot(data=df,x='PetalWidthCm')
# Out:
# <Axes: xlabel='PetalWidthCm', ylabel='Density'>

# %%
sns.scatterplot(data=df,x='SepalLengthCm',y='SepalWidthCm')
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
sns.scatterplot(data=df,x='PetalLengthCm',y='PetalWidthCm')
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %%
sns.regplot(data=df,x='SepalLengthCm',y='SepalWidthCm')
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
sns.regplot(data=df,x='PetalLengthCm',y='PetalWidthCm')
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %%
sns.barplot(x='Species',y='SepalLengthCm',data=df)
# Out:
# <Axes: xlabel='Species', ylabel='SepalLengthCm'>

# %%
sns.barplot(x='Species',y='SepalWidthCm',data=df)
# Out:
# <Axes: xlabel='Species', ylabel='SepalWidthCm'>

# %%
sns.barplot(x='Species',y='PetalLengthCm',data=df)
# Out:
# <Axes: xlabel='Species', ylabel='PetalLengthCm'>

# %%
sns.barplot(x='Species',y='PetalWidthCm',data=df)
# Out:
# <Axes: xlabel='Species', ylabel='PetalWidthCm'>
